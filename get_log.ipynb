# %%
import parse_log as log

# %%
log.plot_near('2022-05-26 05:19:30', 1200)

# %%
log.plot_near('2022-05-26 05:19:30', 60)

# %%
log.plot_near('2022-05-29 05:19:30', 36000)

# %%
dateimes_osc, ch1, ch2, ch3, dateimes_mulimeter, I = log.get_near('2022-05-26 05:19:30', 60)
for time, v in zip(dateimes_osc, ch1):
    print(time, f'oscilloscope channel 1: {v:.2f} V')
# Out:
# 2022-05-26 05:18:37 oscilloscope channel 1: 36.34 V
# 2022-05-26 05:18:51 oscilloscope channel 1: 36.36 V
# 2022-05-26 05:19:03 oscilloscope channel 1: 37.40 V
# 2022-05-26 05:19:16 oscilloscope channel 1: 37.90 V
# 2022-05-26 05:19:29 oscilloscope channel 1: 38.34 V
# 2022-05-26 05:19:42 oscilloscope channel 1: 38.91 V
# 2022-05-26 05:19:55 oscilloscope channel 1: 39.41 V
# 2022-05-26 05:20:09 oscilloscope channel 1: 39.42 V
# 2022-05-26 05:20:22 oscilloscope channel 1: 39.41 V
